# %% [markdown]
# Importing library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('adult.csv')
df
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 0       25           Private  226802          11th                7
# 1       38           Private   89814       HS-grad                9
# 2       28         Local-gov  336951    Assoc-acdm               12
# 3       44           Private  160323  Some-college               10
# 4       18                 ?  103497  Some-college               10
# 5       34           Private  198693          10th                6
# 6       29                 ?  227026       HS-grad                9
# 7       63  Self-emp-not-inc  104626   Prof-school               15
# 8       24           Private  369667  Some-college               10
# 9       55           Private  104996       7th-8th                4
# 10      65           Private  184454       HS-grad                9
# 11      36       Federal-gov  212465     Bachelors               13
# 12      26           Private   82091       HS-grad                9
# ...

# %%
x=df.replace('?',np.NaN).sum()

# %%
x=pd.DataFrame(x)
x[0].plot.hist()

# %%
df[(df['workclass']=='?') | (df['occupation']=='?')]
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 4       18             ?  103497  Some-college               10
# 6       29             ?  227026       HS-grad                9
# 13      58             ?  299831       HS-grad                9
# 22      72             ?  132015       7th-8th                4
# 35      65             ?  191846       HS-grad                9
# 75      17             ?  165361          10th                6
# 89      41             ?   38434       Masters               14
# 100     51             ?  189762  Some-college               10
# 113     20             ?   30796       HS-grad                9
# 132     20             ?  334105       HS-grad                9
# 182     28             ?  168524       HS-grad                9
# 185     64             ?  201368  Some-college               10
# 193     79             ?   48574       7th-8th                4
# 228     25             ?  270276           9th                5
# ...

# %%
df['income']=df['income'].replace(['<=50K','>50K'],[0,1])
df['gender']=df['gender'].replace(['Male','Female'],[0,1])

# %%
df.plot.line('gender','income')
plt.show()

# %%
for i in df.columns:
    print(df[i].value_counts(),'\n-------\n')
# Out:
# 36    1348
# 35    1337
# 33    1335
# 23    1329
# 31    1325
# 34    1303
# 37    1280
# 28    1280
# 30    1278
# 38    1264
# 32    1253
# 41    1235
# 27    1232
# 29    1223
# 39    1206
# 24    1206
# 25    1195
# 40    1187
# 22    1178
# 42    1165
# 26    1153
# 20    1113
# 43    1104
# 46    1097
# 21    1096
# 45    1096
# 47    1081
# 44    1067
# 19    1053
# 51     877
#       ...
# 60     449
# 62     394
# 64     340
# 63     335
# 65     284
# 67     238
# 66     237
# 68     178
# 69     149
# 70     133
# 72     120
# 71     118
# 73     108
# 74      77
# 75      72
# 76      69
# 90      55
# 77      54
# 80      38
# 81      37
# 78      34
# 79      30
# 82      15
# 84      13
# 83      11
# 88       6
# 85       5
# 87       3
# 89       2
# 86       1
# Name: age, dtype: int64
# -------
#
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# ...

# %%
df['marital-status'].replace(['Never-married', 'Married-civ-spouse' ,'Widowed', 'Divorced' ,'Separated'
, 'Married-spouse-absent' ,'Married-AF-spouse'],[0,1,2,3,4,5,6])
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
# 5        0
# 6        0
# 7        1
# 8        0
# 9        1
# 10       1
# 11       1
# 12       0
# 13       1
# 14       1
# 15       1
# 16       0
# 17       1
# 18       2
# 19       1
# 20       1
# 21       0
# 22       3
# 23       0
# 24       1
# 25       1
# 26       0
# 27       4
# 28       1
# 29       0
#         ..
# 48812    0
# 48813    1
# 48814    1
# 48815    3
# 48816    0
# 48817    0
# 48818    0
# 48819    3
# 48820    1
# 48821    4
# 48822    4
# 48823    1
# 48824    3
# 48825    3
# 48826    1
# 48827    3
# 48828    1
# 48829    0
# 48830    3
# 48831    1
# 48832    1
# 48833    1
# 48834    0
# 48835    1
# 48836    0
# 48837    1
# 48838    1
# 48839    2
# 48840    0
# 48841    1
# Name: marital-status, dtype: int64

# %%
df[(df['education']=='Bachelors') | (df['education']=='Masters')]
# Out:
#        age         workclass  fnlwgt  education  educational-num  \
# 11      36       Federal-gov  212465  Bachelors               13
# 15      43           Private  346189    Masters               14
# 20      34           Private  107914  Bachelors               13
# 23      25           Private  220931  Bachelors               13
# 24      25           Private  205947  Bachelors               13
# 32      24  Self-emp-not-inc  188274  Bachelors               13
# 36      36         Local-gov  403681  Bachelors               13
# 40      65           Private  136384    Masters               14
# 57      34         Local-gov  382078  Bachelors               13
# 60      30           Private  101135  Bachelors               13
# 62      26           Private   31208    Masters               14
# 65      41           Private  109912  Bachelors               13
# 81      23           Private  213734  Bachelors               13
# ...

# %%
r=df.groupby('workclass')['income']
